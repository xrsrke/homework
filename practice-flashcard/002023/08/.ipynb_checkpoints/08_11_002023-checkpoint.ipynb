# %% [markdown]
# ### MechInterp

# %%
import torch
from torch import nn
import torch.nn.functional as F

# %%
step 1: compute the normalized loss / n_batch
step 2:

# %%
int* ptr = (int*)malloc(69)

# %%
param_per_ranks = [[] for _ in range(world_size)]
numel_per_rank = [0 for _ in range(world_size)]

# %%
sorted_params = sorted(param_list, key=lambda x: x.numel(), reversed=True)

# %%
for param in sorted_params:
    rank_to_go = numel_per_rank.index(min(numel_per_rank))

# %%
3 notifications, hostdiscovery, torchstate, elasticdriver

# %%
from copy import deepcopy

# %%
def get_handler(value):
    for handler_type, handler_cls in handler_registry:
        if isinstance(value, handler_type):
            return handler_cls(value)
    
    return None

# %%
def get_handlers(states):
    handlers, remainders = {}, {}
    
    for name, value in states:
        handler = get_handler(value)
        
        if handler is None:
            remainders[name] = value
        else:
            handlers[name] = handler

# %%
class ModelStateHandler:
    def __init__(self, model):
        self.set_value(model)
        self.commit()
    
    def set_value(self, value):
        self.model = value
        
    def commit(self):
        self._saved_model_state = deepcopy(self.model.state_dict())
    
    def restore(self):
        self.model.load_state_dict(
            self._saved_model_state
        )

# %%
step 1: init epoch, number of processed data
step 2: get the unprocessed data
step 3: number of workers
step 4: part

# %%
step 1: get the global rank of the current process
step 2: resize embedding vocab size
step 3: parallelize embedding layer, linear, layer norm, attention
step 4:

# %%
numel_per_rank = [0 for _ in range(world_size)]
param_per_rank = [[] for _ in range(world_size)]

# %%
sorted_params = sorted(
    parameter_list,
    key=lambda x: x.numel(),
    reverse=True
)

# %%
for param in sorted_params:
    rank_to_go = numel_per_rank.index(min(numel_per_rank))
    param_per_rank[rank].append(rank)
    numel_per_rank[rank] += param.numel()

# %%
step 1: normalize the loss: loss / current_epoch
step 2: calculate the grads with repsect to the normalized loss
step 3: accumlate the gradients
step 4: if current_epoch == n_epoch, update, otherwise, step 1

# %%
import torch.distributed as dist

# %%
for group in groups:
    dist.barrier()
    dist.destroy_process_group(group=group)

# %%
elastic, hostdiscovery, 3 notifications, torchstate

# %%
data prefetching
lazy loading

# %%
step 1: split the

# %%
Forward(x) > output = Forward(x) > Backward(output)

# %%
(n-1)*n

# %%
clean_tokens = model.to_tokens(clean_prompt)
corrupted_tokens = model.to_tokens(corrupted_prompt)

# %%
correct_token = model.to_single_token(" John")
incorrect_token = model.to_single_token(" Mary")

# %%
from transformer_lens.utils import get_act_name

# %%
seq_len = clean_tokens.shape[-1]

# %%
clean_activations = model.run_with_cache(clean_tokens)
corrupted_activations = model.run_with_cache(corrupted_tokens)

# %%
def patch_resid(resid, hook, clean_activations, position_idx):
    resid[:, position_idx, :] = clean_activations[hook.name][:, position_idx, :]
    return reisd

# %%
from functools import partial

# %%
def compute_logit_difference(logits, correct_token, incorrect_token):
    final_logits = logits[:, -1, :]
    return final_logits[:, correct_token] - final_logits[:, incorrect_token]

# %%
patched_residual_stream_diff = torch.zeros(n_layers, seq_ken)

# %%
for layer_idx in range(n_layers):
    hook_name = get_act_name("resid_pre", layer_idx)
    for position_idx in range(seq_len):
        hook_func = partial(patch_resid, position_idx=position_idx, clean_activations=clean_activations)
        patched_logits = model.run_with_hooks(
            corrupted_tokens,
            fwd_hooks=[(hook_name, hook_func)]
        )
        logit_diff = compute_logit_difference(patched_logits, correct_token, incorrect_token)
        patched_residual_stream_diff[layer_idx][position_idx] = logit_diff

# %%
_, cache = model.run_with_cache(board_history)

# %%
layer_idx = 5
neuron_idx = 1393

# %%
mlp_acts = cache[hook_name]
neuron_acts = mlp_acts[:, neuron_idx]

# %%
threashold = neuron_acts.quantile(0.99)

# %%
moves_idx = neuron_acts > threashold

# %%
opponent_moves == board_states == 1

# %%
_, cache = model.run_with_cache(tokens)

# %%
embed = cache["embed"]

# %%
target_tokens = tokens[1:]

# %%
from einops import einsum

# %%
einsum(
    model.W_U[:, target_tokens],
    embed[:-1]
)

# %% [markdown]
# step 1: diverse data distribution
# step 2: record the activation of the target neuron
# step 3: extract the attention pattern between the target query position and other positions
# step 4: take the average attention pattern across batch
# step 5: plot

# %%
induction_score

# %%
tokens = model.to_tokens(text)

# %%
logits = model(tokens)

# %%
log_probs = F.log_softmax(logits[:, -1, :], dim=-1)

# %%
target_tokens = tokens[1:]

# %%
predicted_log_probs = log_probs.gather(index=target_tokens)

# %%
MLP(Attnb)

# %%
tokens = model.to_tokens(text)

# %%
_, cache = model.run_with_cache(tokens)

# %%
embed = cache["embed"]
pos_embed = cache["pos_embed"]

# %%
W_U = model.W_U
logit_difference_direction = W_U[:, correct_token] - W_U[:, incorrect_token]

# %%
_, cache = model.run_with_cache(tokens)

# %%
resid = cache[final_residual_name]
final_resid = final_resid[:, -1, :]
scaled_final_resid = model.apply_ln_sto_stack(final_resid, layer=-1, pos_slice=-1)

# %%
logit_difference = einsum(
    scaled_final_resid,
    logit_difference_direction
)

# %%
from einops import reduce

# %%
reduce(
    induction_stripe,
    "head_idx seq_len -> head_idx",
    reduction="mean"
)

# %%
step 1: record all the interdimate actiavtions
step 2: spot induction head
step 3: decompose the attetion scores of the induction heads
step 4: trace back which early head exhibit induction pattern
step 5:

# %%
name mover head, s-in, duplication head

# %%
step 1: extract f1
step 2: extract board history before the target move
step 3: run
step 4: patch
step 5: continue

# %%
step 1: prob[0] = sigmoid(logit0 - logit1)
step 2: logit0 = resid2 @ W_U[0], logit1 = resid2 @ W_U[1]
step 3: logit0 - logit1 = resid2 @ (W_U[0] - W_U[1])
step 4: resid2 = resid1 @ ln2 @ W_OV^{2, 0}
step 5: resid1 @ ln2 @ W_OV^{2, 0} @ (W_U[0] - W_U[1])

# %%
corrupted_prompts = [
    "When John and Mary went to the shops, Mary gave the bag to",
    "When Tom and James went to the park, Tom gave the ball to"
]

# %%
clean_tokens = model.to_tokens(clean_prompts)
corrupted_tokens = model.to_tokens(corrupted_prompts)

# %%
correct_tokens = model.to_tokens("Mary James", prepend_bos=True)
incorrect_tokens = model.to_tokens("John James")

# %%
clean_logits = model.run_with_hooks(clean_tokens)
corrupted_logits = model.run_with_hooks(corrupted_tokens)

# %%
def compute_logit_diff(logits, correct_tokens, incorrect_Tokens):
    return (logits[:, -1, :][:, correct_tokens] - logits[:, -1, incorrect_tokens]).mean()

# %%
clean_logit_diff = compute_logit_diff(clean_logits, correct_tokens, incorrect_tokens)
corrupted_logit_diff = compute_logit_diff(corrupted_logits, correct_tokens, incorrect_tokens)

# %%
def compute_ioi_metric(patched_logits):
    return (patched_logits - corrupted_logit_diff)/(clean_logit_diff - corrupted_logit_diff)

# %%
_, cache = model.run_with_cache(board_history)

# %%
layer_idx, neuron_idx = 5, 1393

# %%
mlp_acts = cache[hook_name]
neuron_acts = mlp_acts[:, neuron_idx]

# %%
threashold = neuron_acts.quantile(0.99)

# %%
move_idxs = neuron_acts > threashold

# %%
(board_states == 1)[move_idxs]

# %%
tokens = model.to_tokens(text)

# %%
_, cache = model.run_with_cache(tokens)

# %%
input_components = torch.tensor([
    cache["embed"],
    cache["pos_embed"],
    cache["result", layer_idx-1]
])

# %%
W_Q = model.W_Q[layer_idx, head_idx]
query_components = einsum(
    input_components,
    W_Q
)

# %%
W_K = model.W_K[layer_idx, head_idx]
key_components = einsum(
    input_components,
    W_K
)

# %%
decomposed_attention_scores = einsum(
    query_components,
    key_components,
    ""
)

# %%
MLP(Attn(x@W_E))@W_U

# %%
class SelfAttention(nn.Module):
    def __init__(self, d_head):
        super().__init__()
        self.d_head = d_head
    
    def forward(self, q, k, v, mask = None):
        k = k.permute(-2, -1)
        qk = torch.matmul(q, k)
        
        if mask is not None:
            qk = qk.masked_fill(mask, -1e9)
        
        attn_pattern = F.softmax(qk / (self.d_head * 0.5), dim=-1)
        output = torch.matmul(attn_pattern, v)
        return output, attn_pattern

# %%
step 1: n_worke

# %%
reasoning
generaliz

# %%
dis, search space, induction bias

# %%
from transformers import AutoModel

# %%
model = AutoModel.from_pretrained("gpt2")

# %%
params = list(model.parameters())

# %%
from torch.optim import SGD

# %%
optim = SGD(model.parameters(), lr=0.1)

# %%
optim.parameters()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 optim.parameters()
#
# AttributeError: 'SGD' object has no attribute 'parameters'

# %%
for param_group in params:
    print(param_group["params"])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 for param_group in params:
# ----> 2     print(param_group["params"])
#
# IndexError: too many indices for tensor of dimension 2

# %%
import copy


class TensorParallelInfo(object):
    """
    A class to describe tensor parallelization information.

    Args:
        name (Tuple[str]): the name of module
        combined_qkv (bool): combined qkv or not
        parallel (bool): parallelizable param or not
        reverse (bool): reversed param or not
        gather_output (bool): gather output or not
    """

    def __init__(
        self,
        *name,
        combined_qkv: bool = False,
        reversed: bool = False,
        gather_output: bool = False,
    ):
        self.name = name
        self.combined_qkv = combined_qkv
        self.reversed = reversed
        self.gather_output = gather_output

    def __str__(self):
        return f"{self.__class__.__qualname__}({self.name})"

    def __repr__(self):
        return self.__str__()


Column = type("Column", (TensorParallelInfo,), {})
Row = type("Row", (TensorParallelInfo,), {})
Update = type("Update", (TensorParallelInfo,), {})
Head = type("Head", (TensorParallelInfo,), {})
Other = type("Other", (TensorParallelInfo,), {})
Default = TensorParallelInfo()


class TensorParallelMapping(object):
    __MAPPING__ = {}

    def __init__(self, tp_mapping=None):
        if isinstance(tp_mapping, dict):
            self.__MAPPING__.update(tp_mapping)
        elif tp_mapping is not None:
            raise ValueError("The argument `tp_mapping` must be None or dict.")

        cache_mapping = {}
        for cls, mapping in self.__MAPPING__.items():
            cache_mapping[cls] = []

            for elem in mapping:
                for name in elem.name:
                    copy_elem = copy.deepcopy(elem)
                    copy_elem.name = name
                    cache_mapping[cls].append(copy_elem)

        self.__MAPPING__ = {cls: {} for cls in cache_mapping}
        # clear exist mapping rather than making new mapping dict

        for cls, mapping in cache_mapping.items():
            for elem in mapping:
                if elem.__class__.__qualname__ in self.__MAPPING__[cls]:
                    self.__MAPPING__[cls][elem.__class__.__qualname__].append(elem)
                else:
                    self.__MAPPING__[cls][elem.__class__.__qualname__] = [elem]

    def get_mapping(self, model):
        """
        Get mapping by model obj

        Args:
            model (PreTrainedModel): model object (e.g. BertForSequenceClassification)

        Returns:
            dict: mapping by model
        """
        mapping_by_model = None
        for cls, mapping in self.__MAPPING__.items():
            if isinstance(model, cls):
                mapping_by_model = mapping

        assert mapping_by_model is not None, (
            f"Currently, {model.__class__.__qualname__} is not supported. "
            f"The current supported models are {list(self.__MAPPING__.keys())}"
        )
        return mapping_by_model

    def column_parallel_params(self, model):
        """
        Get list of column parallel param elements

        Args:
            model (PreTrainedModel): model obj

        Returns:
            List[Column]: list of column parallel param elements
        """
        mapping = self.get_mapping(model)
        if mapping is not None:
            return mapping["Column"]

    def row_parallel_params(self, model):
        """
        Get list of row parallel param elements

        Args:
            model (PreTrainedModel): model obj

        Returns:
            List[Row]: list of row parallel param elements
        """
        mapping = self.get_mapping(model)
        if mapping is not None:
            return mapping["Row"]

    def update_attrs(self, model):
        """
        Get list of update attribute elements

        Args:
            model (PreTrainedModel): model obj

        Returns:
            List[Update]: list of update attribute elements
        """
        mapping = self.get_mapping(model)
        if mapping is not None:
            return mapping["Update"]

    def search(self, model, module_name):
        """
        Get element by parameter name

        Args:
            model (PreTrainedModel): model obj

        Returns:
            TensorParallelInfo: element by parameter name
        """
        mapping = self.get_mapping(model)
        count_contain_elem_in_param = 0
        param_split = module_name.split(".")
        first_check = []

        for elems in mapping.values():
            for elem in elems:
                if elem.name in module_name:
                    first_check.append(elem)

        for elem in first_check:
            elem_split = elem.name.split(".")
            for split in elem_split:
                if split in param_split:
                    count_contain_elem_in_param += 1
            if count_contain_elem_in_param == len(elem_split):
                return elem
        return None

    def get_combined_qkv_degree(self, model, module_name, module):
        """
        Get combined qkv degree

        Args:
            model (PreTrainedModel): model obj
            module_name (str): name of module
            module (nn.Module): module that has `weight` parameter

        Returns:
            int: combined qkv degree
        """
        if self.is_combined_qkv_param(model, module_name) and hasattr(module, "weight"):
            bigger = max(module.weight.size(0), module.weight.size(1))
            smaller = min(module.weight.size(0), module.weight.size(1))
            return bigger // smaller
        return 1

    def is_column_parallel(self, model, module_name):
        """
        Check whether the moduleeter is column parallelizable or not

        Args:
            model (PreTrainedModel): model obj
            module_name (str): name of module

        Returns:
            bool: whether the module is column parallelizable or not
        """
        elem = self.search(model, module_name)
        if elem is not None:
            return isinstance(elem, Column)
        return False

    def is_row_parallel(self, model, module_name):
        """
        Check whether the moduleeter is row parallelizable or not

        Args:
            model (PreTrainedModel): model obj
            module_name (str): name of module

        Returns:
            bool: whether the module is row parallelizable or not
        """
        elem = self.search(model, module_name)
        if elem is not None:
            return isinstance(elem, Row)
        return False

    def is_head(self, model, module_name):
        """
        Check whether the moduleeter is head or not

        Args:
            model (PreTrainedModel): model obj
            module_name (str): name of module

        Returns:
            bool: whether the module is head or not
        """
        elem = self.search(model, module_name)
        if elem is not None:
            return isinstance(elem, Head)
        return False

    def is_combined_qkv_param(self, model, module_name):
        """
        Check whether the module is combined qkv or not

        Args:
            model (PreTrainedModel): model obj
            module_name (str): name of module

        Returns:
            bool: whether the module is combined qkv or not
        """
        elem = self.search(model, module_name)
        if elem is not None:
            return elem.combined_qkv
        return Default.combined_qkv

    def is_reversed(self, model, module_name):
        """
        Check whether the moduleeter is reversed or not

        Args:
            model (PreTrainedModel): model obj
            module_name (str): name of module

        Returns:
            bool: whether the module is reversed or not
        """
        elem = self.search(model, module_name)
        if elem is not None:
            return elem.reversed
        return Default.reversed

    def is_gather_output(self, model, module_name):
        """
        Check whether the module is gather output or not

        Args:
            model (PreTrainedModel): model obj
            module_name (str): name of module

        Returns:
            bool: whether the module is gather output or not
        """
        elem = self.search(model, module_name)
        if elem is not None:
            return elem.gather_output
        return Default.gather_output

# %%
type(model.h[-1].mlp.c_fc)
# Out:
# transformers.pytorch_utils.Conv1D

# %%
model = AutoModel.from_pretrained("bigscience/bloom-560m")

# %%
model.h[-1].mlp
# Out:
# BloomMLP(
#   (dense_h_to_4h): Linear(in_features=1024, out_features=4096, bias=True)
#   (gelu_impl): BloomGelu()
#   (dense_4h_to_h): Linear(in_features=4096, out_features=1024, bias=True)
# )

# %%
model
# Out:
# BloomModel(
#   (word_embeddings): Embedding(250880, 1024)
#   (word_embeddings_layernorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   (h): ModuleList(
#     (0-23): 24 x BloomBlock(
#       (input_layernorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (self_attention): BloomAttention(
#         (query_key_value): Linear(in_features=1024, out_features=3072, bias=True)
#         (dense): Linear(in_features=1024, out_features=1024, bias=True)
#         (attention_dropout): Dropout(p=0.0, inplace=False)
#       )
#       (post_attention_layernorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (mlp): BloomMLP(
#         (dense_h_to_4h): Linear(in_features=1024, out_features=4096, bias=True)
#         (gelu_impl): BloomGelu()
#         (dense_4h_to_h): Linear(in_features=4096, out_features=1024, bias=True)
#       )
#     )
#   )
#   (ln_f): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
# )

# %%
optim = SGD(model.parameters(), lr=0.1)

# %%
len(optim.param_groups)
# Out:
# 1

# %%
optim.param_groups[0]["params"]
# Out:
# [Parameter containing:
#  tensor([[-0.0099, -0.0048, -0.0111,  ..., -0.0426,  0.0099,  0.0212],
#          [ 0.0048, -0.0127,  0.0138,  ..., -0.0448,  0.0003, -0.0120],
#          [ 0.0065,  0.0239,  0.0050,  ..., -0.0431, -0.0067,  0.0137],
#          ...,
#          [-0.0028, -0.0038, -0.0012,  ..., -0.0252,  0.0013,  0.0012],
#          [-0.0028, -0.0038, -0.0012,  ..., -0.0252,  0.0013,  0.0012],
#          [-0.0028, -0.0038, -0.0012,  ..., -0.0252,  0.0013,  0.0012]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([0.4409, 0.3167, 0.4749,  ..., 0.0816, 0.2927, 0.6006],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-0.0513,  0.0164,  0.0052,  ...,  0.2412,  0.0072, -0.0292],
#         requires_grad=True),
#  Parameter containing:
#  tensor([0.6621, 0.8457, 0.5884,  ..., 3.2090, 0.9180, 0.5586],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-0.0662, -0.0798,  0.0445,  ..., -0.1449, -0.0452,  0.0142],
# ...
