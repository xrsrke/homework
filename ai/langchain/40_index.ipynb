# %% [markdown]
# ### X

# %%
openai_key = "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"

# %% [markdown]
# ### Code

# %%
from langchain.chains import VectorDBQA
from langchain.llms import OpenAI

# %%
from langchain.document_loaders import TextLoader

# %%
loader = TextLoader("./state_of_the_union.txt")

# %%
loader

# %%
from langchain.indexes import VectorstoreIndexCreator

# %%
import os
index = VectorstoreIndexCreator().from_loaders([loader])
# Out:
# Running Chroma using direct local API.
# Using DuckDB in-memory for database. Data will be transient.

# %%
query = "What did the president say about Ketanji Brown Jackson"

# %%
index.query(query)
# Out:
# " The president said that Ketanji Brown Jackson is one of the nation's top legal minds, a former top litigator in private practice, a former federal public defender, and from a family of public school educators and police officers. He also said that she is a consensus builder and has received a broad range of support from the Fraternal Order of Police to former judges appointed by Democrats and Republicans."

# %%
index.query_with_sources(query)
# Out:
# {'question': 'What did the president say about Ketanji Brown Jackson',
#  'answer': " The president said that he nominated Circuit Court of Appeals Judge Ketanji Brown Jackson, one of the nation's top legal minds, who will continue Justice Breyer's legacy of excellence, and that she has received a broad range of support from the Fraternal Order of Police to former judges appointed by Democrats and Republicans.\n",
#  'sources': './state_of_the_union.txt'}

# %% [markdown]
# ##### Example 1

# %%
loader

# %% [markdown]
# Search the `loader` as bellow using a wrapper (in a one line)

# %%
from langchain.indexes import VectorstoreIndexCreator

# %%
index = VectorstoreIndexCreator().from_loaders([loader])
# Out:
# Running Chroma using direct local API.
# Using DuckDB in-memory for database. Data will be transient.
# Exiting: Cleaning up .chroma directory

# %%
query = "How many speakers in the passage?"

# %%
index.query(query)
# Out:
# ' One speaker.'

# %% [markdown]
# ##### Example 2

# %%
texts = [
    "Persistence is all you need",
    "X42"
]

# %% [markdown]
# Embed `texts` using embedding from OpenAI

# %%
from langchain.embeddings import OpenAIEmbeddings

# %%
embeddings = OpenAIEmbeddings()

# %%
embeded_texts = embeddings.embed_documents(texts)

# %%
len(texts), len(embeded_texts)
# Out:
# (2, 2)

# %%
embeded_texts
# Out:
# [[0.02698628231883049,
#   0.029494790360331535,
#   0.04063785448670387,
#   -0.027540793642401695,
#   -0.022404950112104416,
#   0.006145848426967859,
#   -0.003898091847077012,
#   -0.028993088752031326,
#   0.004802475683391094,
#   -0.03210892155766487,
#   0.012608560733497143,
#   0.021718410775065422,
#   0.012199277989566326,
#   0.01988323964178562,
#   0.0031900980975478888,
#   0.002983806189149618,
#   0.04040020704269409,
#   -0.007294481620192528,
#   0.009631356224417686,
#   -0.018470551818609238,
#   -0.0009489427320659161,
#   -0.010535740293562412,
#   -0.0054956162348389626,
#   -0.0039046930614858866,
#   -0.0016825167695060372,
#   -0.014456936158239841,
#   0.022867044433951378,
#   -0.010397111997008324,
#   -0.0004394017450977117,
#   -0.01514347642660141,
#   0.031052706763148308,
#   -0.000968746782746166,
#   -0.004023517481982708,
#   -0.006178854964673519,
#   -0.01124208327382803,
#   0.010337700136005878,
#   0.0034591027069836855,
# ...
