# %% [markdown]
# - Node (Vertex): stores data
# - Edge: link connections

# %%
class Graph:
    def __init__(self, nodes, edges):
        self.nodes = set(nodes)
        self.edges = set(frozenset((u, v)) for u, v in edges)
    
    def degree(self, node):
        return sum(1 for edge in self.edges if node in edge)

# %%
g1 = Graph([1, 2, 3], {(1, 2), (2, 3)})

# %%
g1.edges
# Out:
# {frozenset({2, 3}), frozenset({1, 2})}

# %%
g1.degree(2)
# Out:
# 2

# %%
# !pip install graphviz
# Out:
# ...
#   Using cached graphviz-0.20.1-py3-none-any.whl (47 kB)
# ...

# %%
import graphviz  # doctest: +NO_EXE

# %%
dot = graphviz.Digraph(comment='The Round Table')

# %%
dot

# %%
dot.node('A', 'King Arthur')  # doctest: +NO_EXE
dot.node('B', 'Sir Bedevere the Wise')
dot.node('L', 'Sir Lancelot the Brave')

dot.edges(['AB', 'AL'])
dot.edge('B', 'L', constraint='false')

# %%
print(dot.source)
# Out:
# // The Round Table
# digraph {
# 	A [label="King Arthur"]
# 	B [label="Sir Bedevere the Wise"]
# 	L [label="Sir Lancelot the Brave"]
# 	A -> B
# 	A -> L
# 	B -> L [constraint=false]
# }

# %%
doctest_mark_exe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [35], line 1
# ----> 1 doctest_mark_exe()
#
# NameError: name 'doctest_mark_exe' is not defined

# %%
dot.render('doctest-output/round-table.gv').replace('\\', '/')
# Out:
# 'doctest-output/round-table.gv.pdf'

# %%
chem = graphviz.Digraph(comment='Chemistry')

# %%
chem.node('mass', 'Mass')
chem.node('mole', 'Mole')
chem.node('pressure', 'Pressure')
chem.node('volume', 'Volume')
chem.node('temperature', 'Temperature')

# %%
dot.edges??
# Out:
# Signature: dot.edges(tail_head_iter) -> None
# Source:
#     def edges(self, tail_head_iter) -> None:
#         """Create a bunch of edges.
#
#         Args:
#             tail_head_iter: Iterable of ``(tail_name, head_name)`` pairs
#                 (format:``node[:port[:compass]]``).
#
#
#         Note:
#             The ``tail_name`` and ``head_name`` strings are separated
#             by (optional) colon(s) into ``node`` name, ``port`` name,
#             and ``compass`` (e.g. ``sw``).
#             See :ref:`details in the User Guide <node-ports-compass>`.
#         """
#         edge = self._edge_plain
#         quote = self._quote_edge
#         self.body += [edge(tail=quote(t), head=quote(h))
#                       for t, h in tail_head_iter]
# File:      /opt/homebrew/lib/python3.10/site-packages/graphviz/dot.py
# Type:      method

# %%
chem.edge('mass', 'mole')

# %%
chem.edge('mass', 'mole')

# %%
print(chem.source)
# Out:
# // Chemistry
# digraph {
# 	mass [label=Mass]
# 	mole [label=Mole]
# 	pressure [label=Pressure]
# 	volume [label=Volume]
# 	temperature [label=Temperature]
# 	mass -> mole
# 	mass -> mole
# }

# %%
chem.view()
# Out:
# 'Digraph.gv.pdf'

# %% [markdown]
# ### Cluster

# %%
from graphviz import Digraph

g = Digraph('G', filename='cluster.gv')

# NOTE: the subgraph name needs to begin with 'cluster' (all lowercase)
#       so that Graphviz recognizes it as a special cluster subgraph

with g.subgraph(name='cluster_0') as c:
    c.attr(style='filled', color='lightgrey')
    c.node_attr.update(style='filled', color='white')
    c.edges([('a0', 'a1'), ('a1', 'a2'), ('a2', 'a3')])
    c.attr(label='process #1')

with g.subgraph(name='cluster_1') as c:
    c.attr(color='blue')
    c.node_attr['style'] = 'filled'
    c.edges([('b0', 'b1'), ('b1', 'b2'), ('b2', 'b3')])
    c.attr(label='process #2')

g.edge('start', 'a0')
g.edge('start', 'b0')
g.edge('a1', 'b3')
g.edge('b2', 'a3')
g.edge('a3', 'a0')
g.edge('a3', 'end')
g.edge('b3', 'end')

g.node('start', shape='Mdiamond')
g.node('end', shape='Msquare')

g.view()
# Out:
# 'cluster.gv.pdf'

# %%
from graphviz import Digraph

g = Digraph('G', filename='cluster.gv')

# NOTE: the subgraph name needs to begin with 'cluster' (all lowercase)
#       so that Graphviz recognizes it as a special cluster subgraph

with g.subgraph(name='cluster_ideal_gas_law') as c:
    c.attr(style='filled', color='lightgrey')
    c.node_attr.update(style='filled', color='white')
    c.edges([('a0', 'a1'), ('a1', 'a2'), ('a2', 'a3')])
    c.attr(label='ideal gas law')

# with g.subgraph(name='cluster_1') as c:
#     c.attr(color='blue')
#     c.node_attr['style'] = 'filled'
#     c.edges([('b0', 'b1'), ('b1', 'b2'), ('b2', 'b3')])
#     c.attr(label='process #2')

with g.subgraph(name='cluster_mass_mole') as c:
    c.attr(color='yello')
    c.node_attr['style'] = 'filled'
    c.edges([('b0', 'b1'), ('b1', 'b2'), ('b2', 'b3')])
    c.attr(label='Mass Mole Conversion')

g.edge('start', 'a0')
g.edge('start', 'b0')
g.edge('a1', 'b3')
g.edge('b2', 'a3')
g.edge('a3', 'a0')
g.edge('a3', 'end')
g.edge('b3', 'end')

g.node('start', shape='Mdiamond')
g.node('end', shape='Msquare')

g.view()
# Out:
# ...
# 'cluster.gv.pdf'
