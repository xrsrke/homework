# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
import matplotlib
matplotlib.get_backend()
# Out:
# 'module://matplotlib_inline.backend_inline'

# %%
df = pd.read_csv('./titanic_dataset.csv')

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked
# ...

# %%
fig, ax = plt.subplots()
_ = ax.plot(np.sort(df['age']), marker='o', markersize=1)

# %%
fig, ax = plt.subplots()
_ = ax.plot(np.sort(df['age']), marker='o', markersize=1)

# %%
plt.figure()

# %%
fig, ax = plt.subplots()
_ = ax.plot(np.sort(df['age']), marker='o', markersize=1)
_ = ax.set_title(r"Titanic Dataset $\theta$")
_ = ax.set_ylabel("Ages")
_ = ax.set_xlabel("Number of passengers")
_ = ax.set_yticks([15, 25, 55, 64])
_ = ax.set_yticklabels(['children', 'youth', 'adults', 'seniros'])

# %%
matplot.li
